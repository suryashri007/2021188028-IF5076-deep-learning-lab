# %%
# !pip install "tensorflow>=2.0.0"
# !pip install --upgrade tensorflow-hub
# Out:
# Requirement already satisfied: tensorflow>=2.0.0 in /home/cs/anaconda3/lib/python3.9/site-packages (2.9.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (1.42.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (1.12)
# Requirement already satisfied: h5py>=2.9.0 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (3.6.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (2.9.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (2.9.1)
# Requirement already satisfied: wrapt>=1.11.0 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (1.12.1)
# Requirement already satisfied: absl-py>=1.0.0 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (1.1.0)
# Requirement already satisfied: setuptools in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (61.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (4.1.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (1.1.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (3.19.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (2.9.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (1.16.0)
# Requirement already satisfied: numpy>=1.20 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (1.21.5)
# Requirement already satisfied: termcolor>=1.1.0 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (1.1.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (14.0.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (0.26.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (1.6.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (0.4.0)
# Requirement already satisfied: packaging in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow>=2.0.0) (21.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/cs/anaconda3/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow>=2.0.0) (0.37.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (2.27.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (1.33.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (2.0.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (1.8.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/cs/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/cs/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/cs/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/cs/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/cs/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/cs/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/cs/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /home/cs/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/cs/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (2.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/cs/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.0.0) (3.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/cs/anaconda3/lib/python3.9/site-packages (from packaging->tensorflow>=2.0.0) (3.0.4)
# Collecting tensorflow-hub
#   Downloading tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
#      |████████████████████████████████| 108 kB 143 kB/s eta 0:00:01
# Requirement already satisfied: protobuf>=3.8.0 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow-hub) (3.19.1)
# Requirement already satisfied: numpy>=1.12.0 in /home/cs/anaconda3/lib/python3.9/site-packages (from tensorflow-hub) (1.21.5)
# Installing collected packages: tensorflow-hub
# Successfully installed tensorflow-hub-0.12.0

# %%
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import tempfile
from six.moves.urllib.request import urlopen
from six import BytesIO
import numpy as np
from PIL import Image
from PIL import ImageColor
from PIL import ImageDraw
from PIL import ImageFont
from PIL import ImageOps
import time
import os
import random

# %%
import pathlib
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url, untar=True)
data_dir = pathlib.Path(data_dir)

# %%
# Function to Display Image
def display_image(image,file):
    fig = plt.figure(figsize=(15, 10))
    plt.grid(False)
    plt.imshow(image)
    plt.title(file, fontsize=20)

    
# Function to Resize Image
def resize_image(img, new_width=150, new_height=150,display=False):
    img_path = os.path.join(dataset_url,img)
    pil_image = Image.open(img_path)
    pil_image = ImageOps.fit(pil_image, (new_width, new_height), Image.ANTIALIAS)
    pil_image_rgb = pil_image.convert("RGB")
    if display:
        display_image(pil_image, img)

# %%
# Applying the Function 
resize_image(random.choice(os.listdir(dataset_url)),600,400,True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       1 # Applying the Function
# ----> 2 resize_image(random.choice(os.listdir(dataset_url)),600,400,True)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz'

# %%
# Function to Draw Bounding Boxes on Image
def draw_bounding_box_on_image(image,ymin,xmin,ymax,xmax,color,font,thickness=4,display_str_list=()):
       
    # Adds a bounding box to an image.
    draw = ImageDraw.Draw(image)
    im_width, im_height = image.size
    (left, right, top, bottom) = (xmin * im_width, xmax * im_width,ymin * im_height, ymax * im_height)
    draw.line([(left, top), (left, bottom), (right, bottom), (right, top),(left, top)],width=thickness,fill=color)
    
    # If the total height of the display strings added to the top of the bounding
    # box exceeds the top of the image, stack the strings below the bounding box
    # instead of above.
    display_str_heights = [font.getsize(ds)[1] for ds in display_str_list]
    
    # Each display_str has a top and bottom margin of 0.05x.
    total_display_str_height = (1 + 2 * 0.05) * sum(display_str_heights)
    
    if top > total_display_str_height:
        text_bottom = top
    else:
        text_bottom = top + total_display_str_height
        
    # Reverse list and print from bottom to top.
    for display_str in display_str_list[::-1]:
        text_width, text_height = font.getsize(display_str)
        margin = np.ceil(0.05 * text_height)
        draw.rectangle([(left, text_bottom - text_height - 2 * margin),(left + text_width, text_bottom)],fill=color)
        draw.text((left + margin, text_bottom - text_height - margin),display_str, fill="black", font=font)
        text_bottom -= text_height - 2 * margin
        

# Function to Draw Boxes       
def draw_boxes(image, boxes, class_names, scores, max_boxes=3, min_score=0.1):
    
    # Overlay labeled boxes on an image with formatted scores and label names.
    colors = list(ImageColor.colormap.values())
    font = ImageFont.load_default()
    
    for i in range(min(boxes.shape[0], max_boxes)):
        if scores[i] >= min_score:
            ymin, xmin, ymax, xmax = tuple(boxes[i])
            display_str = "{}: {}%".format(class_names[i].decode("ascii"),int(100 * scores[i]))
            color = colors[hash(class_names[i]) % len(colors)]
            image_pil = Image.fromarray(np.uint8(image)).convert("RGB")
            
            draw_bounding_box_on_image(image_pil,ymin,xmin,ymax,xmax,color,font,display_str_list=[display_str])
            np.copyto(image, np.array(image_pil))
    return image

# %%
# FasterRCNN + InceptionResNet v2 Path Trained on Open Images dataset
model_path = "https://tfhub.dev/google/faster_rcnn/openimages_v4/inception_resnet_v2/1"

# Define Model
PreTrained_Model = hub.load(model_path).signatures['default']

# %%
# Function to Load Image from Random Image Folder using TensorFlow
def load_img(img_file):
    path = os.path.join(random_images,img_file)
    img = tf.io.read_file(path)
    img = tf.image.decode_jpeg(img, channels=3)
    return img

# %%
# Function to Detect Object using TensorFlow's Pretrained Model
def detect(model, img_file):
    
    img = load_img(img_file)
    
    converted_img  = tf.image.convert_image_dtype(img, tf.float32)[tf.newaxis, ...]
    
    start_time = time.time()   # Start Timer
    
    result = model(converted_img)   # Detection Using Pretrained Model downloaded above
    
    end_time = time.time()    # End Timer
    
    result = {key:value.numpy() for key,value in result.items()}
    
    print("Found %d objects." % len(result["detection_scores"]))
    print("Inference time (secs): ",'{:.2}'.format(end_time-start_time))
    
    image_with_boxes = draw_boxes(img.numpy(), result["detection_boxes"],result["detection_class_entities"], result["detection_scores"])
    
    display_image(image_with_boxes,img_file)

# %%
# Running the Detect Function
detect(PreTrained_Model, random.choice(os.listdir(random_images)))
# Out:
# Found 100 objects.
# Inference time (secs):  7.8e+01
